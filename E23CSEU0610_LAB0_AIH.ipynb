# %%
file = open("student.txt", "w")

file.write("Name: Neha\n")
file.write("Roll Number: 205\n")
file.write("Marks: 87\n")

file.close()

print("Data written successfully.")
# Out:
# Data written successfully.

# %%
file = open("student.txt", "r")

data = file.read()

print(data)

file.close()
# Out:
# Name: Neha
# Roll Number: 205
# Marks: 87

# %%
# Writing to a file

with open("student.txt", "w") as file:
    file.write("Name: Karan\n")
    file.write("Marks: 87\n")

# Reading from the file

with open("student.txt", "r") as file:
    data = file.read()

print(data)

with open("student.txt", "a") as file:
    file.write("Grade: A+\n")

print("New data added.")
with open("student.txt", "r") as file:
    data = file.read()
print(data)
# Out:
# Name: Karan
# Marks: 87
#
# New data added.
# Name: Karan
# Marks: 87
# Grade: A+

# %%
import pandas as pd

# Creating data
data = {
    "Name": ["Neha", "Karan", "Simran", "Arjun"],
    "Age": [21, 20, 22, 19],
    "Marks": [91, 84, 89, 76]
}

# Creating DataFrame
df = pd.DataFrame(data)

print(df)
# Out:
#      Name  Age  Marks
# 0    Neha   21     91
# 1   Karan   20     84
# 2  Simran   22     89
# 3   Arjun   19     76

# %%
print(df[["Name", "Marks"]])
# Out:
#      Name  Marks
# 0    Neha     91
# 1   Karan     84
# 2  Simran     89
# 3   Arjun     76

# %%
average = df["Marks"].mean()

print("Average Marks:", average)
# Out:
# Average Marks: 85.0

# %%
print("Highest Marks:", df["Marks"].max())
# Out:
# Highest Marks: 91

# %%
import pandas as pd

df = pd.read_csv("students.csv")

print(df)
# Out:
#      Name  Age  Marks
# 0    Neha   21     91
# 1   Karan   20     84
# 2  Simran   22     89
# 3   Arjun   19     76

# %%
import numpy as np

numbers = np.array([15, 25, 35, 45, 55])

print(numbers)
# Out:
# [15 25 35 45 55]

# %%
import numpy as np

numbers = np.array([15, 25, 35, 45, 55])

print("Addition:", numbers + 5)
print("Subtraction:", numbers - 5)
print("Multiplication:", numbers * 2)
print("Division:", numbers / 2)
# Out:
# Addition: [20 30 40 50 60]
# Subtraction: [10 20 30 40 50]
# Multiplication: [ 30  50  70  90 110]
# Division: [ 7.5 12.5 17.5 22.5 27.5]

# %%
numbers * 2
# Out:
# array([ 30,  50,  70,  90, 110])

# %%
# Matplotlib is used to create graphs and charts in Python.
import matplotlib.pyplot as plt

tests = [1, 2, 3, 4, 5]
marks = [62, 70, 81, 86, 94]

plt.plot(tests, marks)

plt.xlabel("Test Number")
plt.ylabel("Marks")
plt.title("Student Performance")

plt.show()

# %%
import matplotlib.pyplot as plt

tests = [1, 2, 3, 4, 5]
marks = [62, 70, 81, 86, 94]

plt.plot(tests, marks, marker="o")

plt.xlabel("Test Number")
plt.ylabel("Marks")
plt.title("Student Performance")

plt.show()

# %%
import matplotlib.pyplot as plt

students = ["Neha", "Karan", "Simran", "Arjun"]
marks = [91, 84, 89, 76]

plt.bar(students, marks)

plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Student Marks")

plt.show()

# %%
import matplotlib.pyplot as plt

languages = ["Python", "Java", "JavaScript", "C++"]
students = [45, 25, 20, 10]

plt.pie(students, labels=languages, autopct="%1.1f%%")

plt.title("Programming Language Preference")

plt.show()

# %%
import matplotlib.pyplot as plt

study_hours = [2, 3, 4, 5, 6, 7]
marks = [50, 58, 67, 75, 84, 93]

plt.scatter(study_hours, marks)

plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Read CSV file using Pandas
df = pd.read_csv("students.csv")

# Step 2: Display DataFrame
print("Student Data:")
print(df)

# Step 3: Use NumPy for numerical calculations
marks = np.array(df["Marks"])

print("\nAverage Marks:", np.mean(marks))
print("Highest Marks:", np.max(marks))
print("Lowest Marks:", np.min(marks))

# Step 4: Visualize the data
plt.bar(df["Name"], df["Marks"])

plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Student Marks")

plt.show()
# Out:
# Student Data:
#      Name  Age  Marks
# 0    Neha   21     91
# 1   Karan   20     84
# 2  Simran   22     89
# 3   Arjun   19     76
#
# Average Marks: 85.0
# Highest Marks: 91
# Lowest Marks: 76
